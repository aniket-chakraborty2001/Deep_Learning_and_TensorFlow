# %% [markdown]
# ---
# ## Importing TensorFlow library  and other libraries. Check the version of TensorFlow library I am using
# ---

# %%
import numpy as np
import sympy as sp
import sys
import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('dark_background')
from keras.datasets import mnist
# %matplotlib inline
import tensorflow as tf
tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# ## Setting the Printing precision

# %%
np.set_printoptions(precision = 2)

# %% [markdown]
# ## Generating Artificial Data set for This Tutorial

# %%
# Consider there are 5 samples, and each sample has 4 features.
# These samples can belong to 3 output classes (0,1,2)
# The data matrix, samples are arranged column by column
# So, the shape of the data matrix will be (4*5) instead of (5*4)
# The weights matrix is created for the output classes considering all features
# So, shape of the weights matrix will be (3*4)
# We know that Z = WX; so shape of Z is (shape of W)*(Shape of X)
# In other words, the Raw Scores matrix is of shape (3*5)

num_samples = 5
num_features = 4
num_labels = 3

# Creating data matrix of shape (4*5)
X = np.random.choice(np.arange(0, 5), size = (num_features, num_samples), replace = True)

# Creating the Output class labels vectors of shape (5*1)
y = np.random.choice([0, 1, 2], size = num_samples, replace = True)

# Creating the Weights matrix for output classes and features of shape (3*4)
W = np.random.choice(np.arange(-4, 4), size = (num_labels, num_features), replace = True)

print('X = ', X) # shape is (4*5)
print('-----------------------------------------------------')
print('y = ', y) # Shape is (1*5)
print('-----------------------------------------------------')
print('w = ', W) # Shape is (3*4)
# Out:
# X =  [[2 4 0 2 3]
#  [0 4 4 3 1]
#  [2 1 3 4 3]
#  [1 4 4 2 4]]
# -----------------------------------------------------
# y =  [2 0 1 1 0]
# -----------------------------------------------------
# w =  [[-1  3 -2 -2]
#  [ 2  2 -3  2]
#  [ 2  3  0 -3]]

# %% [markdown]
# ## Adding bias feature in the Data matrix (X) and in the Weights Matrix (W) using numpy.
# #### Now, one thing to note that this cell must not be ran more than once, otherwise one more bias feature will be added.
#
# #### So, we add randomly generated bis values in the last column of weights matrix W and assign a row of ones in the Data matrix X

# %%
print('X = ')
print(X)
print('-----------------Adding Bias Feature in the Data Matrix---------------------')
print('X with bias feature = ')
X = np.vstack([X, np.ones((1, num_samples))])
print(X)
# Out:
# X =
# [[2 4 0 2 3]
#  [0 4 4 3 1]
#  [2 1 3 4 3]
#  [1 4 4 2 4]]
# -----------------Adding Bias Feature in the Data Matrix---------------------
# X with bias feature =
# [[2. 4. 0. 2. 3.]
#  [0. 4. 4. 3. 1.]
#  [2. 1. 3. 4. 3.]
#  [1. 4. 4. 2. 4.]
#  [1. 1. 1. 1. 1.]]

# %%
# Adjust the weight matrix and add bias values
# for bias as the last column
W = np.hstack([W, np.ones((num_labels, 1))]) # For simplicity All values are considered as 1
print('Bias Added Weights Matrix is')
print(W)
# Out:
# Bias Added Weights Matrix is
# [[-1.  3. -2. -2.  1.]
#  [ 2.  2. -3.  2.  1.]
#  [ 2.  3.  0. -3.  1.]]

# %% [markdown]
# ## Calculating the Raw Scores Vector Z as Z = WX
# #### We don't consider the term 'b' for bias as it is already accounted in W and X

# %%
Z = np.dot(W,X)
print('Z = ')
print(Z)

print('-------------------------------------------------------------')

print('The Correct lables y =')
print(y)

# Quantify Unhappiness
# In actual, the 0th sample belongs to 2nd output class
# So, to be happy the the 1st sample's Raw Score will be highest for output class 2
# In this case, This is true as 2 is bigger than -7 and 1; that means I am happy
# Again I are happy for the 2nd sample.
# For other samples, I am not happy.
# Out:
# Z =
# [[ -7.  -1.  -1.  -4. -13.]
#  [  1.  22.   8.   3.   8.]
#  [  2.   9.   1.   8.  -2.]]
# -------------------------------------------------------------
# The Correct lables y =
# [2 0 1 1 0]

# %% [markdown]
# ## SoftMax Function and Its Inner working

# %%
# Inner Working of SoftMax Funtion

# Exponentiate (to ommit negative values) and then Normalize (to make the values small)
# Thus we get predicted probabilities for each sample considering the three output classes
print('Z = ')
print(Z)
print('---------')
print('Z_exp = ')
Z_exp = np.exp(Z)
print(Z_exp)
print('---------')
print('Predicted Probabilities Matrix = ')
print(Z_exp/np.sum(Z_exp, axis = 0))
print('---------')
print('Correct Output Class labels')
print(y)

# Interpretation of the predicted Probabilities matrix
# The predicted probability that the 0th sample will belong to output class 0 is 9.02*10^(-5)
# The predicted probability that the 0th sample will belong to output class 1 is 2.69*10^(-1)
# The predicted probability that the 0th sample will belong to output class 2 is 7.31*10^(-1)

# A value close to 1 means we are happy for the sample's output class label.
# An ideal predicted probability vector for the 0th sample will be [0 0 1]^T
# So, the loss is -log(1); which is 0; so 0 unhappiness means I are very happy
# If the predicted probability vector will be [0 0 1]^T and 0 is the actual class label
# Then loss will be -log(0) which is infinity; very unhappy
# Out:
# Z =
# [[ -7.  -1.  -1.  -4. -13.]
#  [  1.  22.   8.   3.   8.]
#  [  2.   9.   1.   8.  -2.]]
# ---------
# Z_exp =
# [[9.12e-04 3.68e-01 3.68e-01 1.83e-02 2.26e-06]
#  [2.72e+00 3.58e+09 2.98e+03 2.01e+01 2.98e+03]
#  [7.39e+00 8.10e+03 2.72e+00 2.98e+03 1.35e-01]]
# ---------
# Predicted Probabilities Matrix =
# [[9.02e-05 1.03e-10 1.23e-04 6.10e-06 7.58e-10]
#  [2.69e-01 1.00e+00 9.99e-01 6.69e-03 1.00e+00]
#  [7.31e-01 2.26e-06 9.11e-04 9.93e-01 4.54e-05]]
# ---------
# Correct Output Class labels
# [2 0 1 1 0]

# %%
# Defining the SoftMax function using def keyword
# Define softmax function
def softmax(Z): # 0th axis means top-bottom
  Z_exp =np.exp(Z - np.max(Z, axis=0)) # To eliminate overflow subtraction is done and then exponentiate it
  return(Z_exp /np.sum(Z_exp,axis= 0)) # Normalization is done in this step

# %% [markdown]
# ## Calculating Predicted Probabilities using the softmax() function just defined in above code cell

# %%
# Calculate the probability matrix
P = softmax(Z)
print('Z = ')
print(Z)
print('-----------')
print('P = ')
print(P)
print('-----------')
# Sum in each column of matrix P
print('Sum of Each Column')
print(np.sum(P,axis= 0))
print('------------')
# Print the correct label for each sample
print('y = ')
print(y)
# Out:
# Z =
# [[ -7.  -1.  -1.  -4. -13.]
#  [  1.  22.   8.   3.   8.]
#  [  2.   9.   1.   8.  -2.]]
# -----------
# P =
# [[9.02e-05 1.03e-10 1.23e-04 6.10e-06 7.58e-10]
#  [2.69e-01 1.00e+00 9.99e-01 6.69e-03 1.00e+00]
#  [7.31e-01 2.26e-06 9.11e-04 9.93e-01 4.54e-05]]
# -----------
# Sum of Each Column
# [1. 1. 1. 1. 1.]
# ------------
# y =
# [2 0 1 1 0]

# %% [markdown]
# ## Calculating The tRaining Loss for all samples and its inner workings

# %%
# Inner working of the Loss function
print('P = ')
print(P)
print('-----------')
print('y = ')
print(y)
print('-----------')
print('A 1*5 matrix = ')
print(np.arange(num_samples))
print('-----------')
print('Predicted Probabilities that Each sample will belong to its correct class')
print(P[y,np.arange(num_samples)])
print('-----------')
print('The Loss is given by')
print(-np.log(P[y,np.arange(num_samples)]))
print('-----------')
print('The Average Loss is given as')
print(np.mean(-np.log(P[y,np.arange(num_samples)])))
# Out:
# P =
# [[9.02e-05 1.03e-10 1.23e-04 6.10e-06 7.58e-10]
#  [2.69e-01 1.00e+00 9.99e-01 6.69e-03 1.00e+00]
#  [7.31e-01 2.26e-06 9.11e-04 9.93e-01 4.54e-05]]
# -----------
# y =
# [2 0 1 1 0]
# -----------
# A 1*5 matrix =
# [0 1 2 3 4]
# -----------
# Predicted Probabilities that Each sample will belong to its correct class
# [7.31e-01 1.03e-10 9.99e-01 6.69e-03 7.58e-10]
# -----------
# The Loss is given by
# [3.13e-01 2.30e+01 1.03e-03 5.01e+00 2.10e+01]
# -----------
# The Average Loss is given as
# 9.864231154223361

# %%
# Defining the Training loss for each sample
loss = -np.log(P[y,np.arange(num_samples)])
print('Loss = ')
print(loss)
print('-----------')
# Calculate average training loss
data_loss = np.mean(loss)
print('Total loss = %f'%(data_loss))
# Out:
# Loss =
# [3.13e-01 2.30e+01 1.03e-03 5.01e+00 2.10e+01]
# -----------
# Total loss = 9.864231

# %% [markdown]
# ## Calculating Regularization Loss and Its Inner workings
# * We don't want the training data to have the model overfit to specific features.
# * Here L1 and L2 regularizations are mostly used.
# * Regularization helps by shrunking the weights values to zero (0) and at the same time, they minimize the average training loss .
# * In case of L1 regularization, most weights values are actually become zero. It is used when the user has pervious knowledge on which feature set matters the most by experience. They identify which features matter the most.
# * In case of L2 regularization, all weights values are shrunk to 0 uniformly, resulting is small weights very close to 0. Used when the user don't know which feature set matters the most.
# * Regularization is not applied on bias values as they don't contribute in overfitting. Bias values are specific to classes and they are not associated with samples. Bias are not applied on original features.

# %%
# Inner Working of Regularization Loss
print('The Weights Matrix W is')
print(W)
print('---------------')
print('The Weights Matrix excluding last Column')
print(W[:,:-1]) # As the last column represents the bias value
print('---------------')
print('Element-wise Product for L2 regularization')
print(W[:,:-1]*W[:,:-1]) # Calculation for the L2 Regularization; elementwise product
# Observe all the entries of W are just squared.
# Out:
# The Weights Matrix W is
# [[-1.  3. -2. -2.  1.]
#  [ 2.  2. -3.  2.  1.]
#  [ 2.  3.  0. -3.  1.]]
# ---------------
# The Weights Matrix excluding last Column
# [[-1.  3. -2. -2.]
#  [ 2.  2. -3.  2.]
#  [ 2.  3.  0. -3.]]
# ---------------
# Element-wise Product for L2 regularization
# [[1. 9. 4. 4.]
#  [4. 4. 9. 4.]
#  [4. 9. 0. 9.]]

# %%
# Calculating Regularizatioin Loss (L2)
reg = 0.1 # strength of regularization = 10%
reg_loss = (np.sum(W[:,:-1]*W[:,:-1])) * reg
print('Total loss = %f'%(data_loss + reg_loss))
# Out:
# Total loss = 15.964231

# %% [markdown]
# ## Calculating Gradient of Total Loss w.r.t to the Weights Matrix

# %%
# Adjust the probability matrix such that 1 is subtracted
# from each samples correct category probability.
P[y, range(num_samples)] = P[y, range(num_samples)] - 1

# Calculate the gradient of total loss w.r.t. the weights W
dW = (1/num_samples)* np.dot(P, X.T)+ reg * 2* np.hstack([W[:,:-1], np.zeros((num_labels,1))])
# np.zeros is added as no update for the bias values are considered
# So, the bias values will be 0
print(dW)

# Interpretation of the gradient object
# Consider three output categories Mild, High and VeryHigh
# The 5 features are HR, BP, Temp, Weight and Glucose
# The values in 0th row and 1st column is -0.4 (Python way of indexing) means
# If I were to tweak the weights for BP as far as the Mild category is considered,
# The loss is going to change
# If I increase the weight value for the BP feature of Mild category,
# The loss will decrease
# Out:
# [[-1.6  -0.4  -1.2  -2.   -0.4 ]
#  [ 1.51  0.8  -0.49  1.66  0.25]
#  [ 0.69  1.2   0.69 -0.26  0.15]]

# %% [markdown]
# ## Applying the Gradient Descent Method To the Data set Created

# %%
alpha = 1e-02 # learning rate
tol = 1e-05 # stopping tolerance
iter = 0
maxiter = 1000

while np.linalg.norm(dW) >tol and iter< maxiter:
  W = W + alpha*(-dW)
  iter = iter+1
  print('Iteration = %d, ||gradL(W)|| = %f'%(iter, np.linalg.norm(dW)))
# Norm of a matrix is the square root of the sum of squared elements of the matrix
# Out:
# Iteration = 1, ||gradL(W)|| = 4.093389
# Iteration = 2, ||gradL(W)|| = 4.093389
# Iteration = 3, ||gradL(W)|| = 4.093389
# Iteration = 4, ||gradL(W)|| = 4.093389
# Iteration = 5, ||gradL(W)|| = 4.093389
# Iteration = 6, ||gradL(W)|| = 4.093389
# Iteration = 7, ||gradL(W)|| = 4.093389
# Iteration = 8, ||gradL(W)|| = 4.093389
# Iteration = 9, ||gradL(W)|| = 4.093389
# Iteration = 10, ||gradL(W)|| = 4.093389
# Iteration = 11, ||gradL(W)|| = 4.093389
# Iteration = 12, ||gradL(W)|| = 4.093389
# Iteration = 13, ||gradL(W)|| = 4.093389
# Iteration = 14, ||gradL(W)|| = 4.093389
# Iteration = 15, ||gradL(W)|| = 4.093389
# Iteration = 16, ||gradL(W)|| = 4.093389
# Iteration = 17, ||gradL(W)|| = 4.093389
# Iteration = 18, ||gradL(W)|| = 4.093389
# Iteration = 19, ||gradL(W)|| = 4.093389
# Iteration = 20, ||gradL(W)|| = 4.093389
# Iteration = 21, ||gradL(W)|| = 4.093389
# Iteration = 22, ||gradL(W)|| = 4.093389
# Iteration = 23, ||gradL(W)|| = 4.093389
# Iteration = 24, ||gradL(W)|| = 4.093389
# Iteration = 25, ||gradL(W)|| = 4.093389
# Iteration = 26, ||gradL(W)|| = 4.093389
# Iteration = 27, ||gradL(W)|| = 4.093389
# Iteration = 28, ||gradL(W)|| = 4.093389
# Iteration = 29, ||gradL(W)|| = 4.093389
# Iteration = 30, ||gradL(W)|| = 4.093389
# Iteration = 31, ||gradL(W)|| = 4.093389
# Iteration = 32, ||gradL(W)|| = 4.093389
# Iteration = 33, ||gradL(W)|| = 4.093389
# Iteration = 34, ||gradL(W)|| = 4.093389
# Iteration = 35, ||gradL(W)|| = 4.093389
# Iteration = 36, ||gradL(W)|| = 4.093389
# Iteration = 37, ||gradL(W)|| = 4.093389
# Iteration = 38, ||gradL(W)|| = 4.093389
# Iteration = 39, ||gradL(W)|| = 4.093389
# Iteration = 40, ||gradL(W)|| = 4.093389
# Iteration = 41, ||gradL(W)|| = 4.093389
# Iteration = 42, ||gradL(W)|| = 4.093389
# Iteration = 43, ||gradL(W)|| = 4.093389
# Iteration = 44, ||gradL(W)|| = 4.093389
# Iteration = 45, ||gradL(W)|| = 4.093389
# Iteration = 46, ||gradL(W)|| = 4.093389
# Iteration = 47, ||gradL(W)|| = 4.093389
# Iteration = 48, ||gradL(W)|| = 4.093389
# Iteration = 49, ||gradL(W)|| = 4.093389
# Iteration = 50, ||gradL(W)|| = 4.093389
# Iteration = 51, ||gradL(W)|| = 4.093389
# Iteration = 52, ||gradL(W)|| = 4.093389
# Iteration = 53, ||gradL(W)|| = 4.093389
# Iteration = 54, ||gradL(W)|| = 4.093389
# Iteration = 55, ||gradL(W)|| = 4.093389
# Iteration = 56, ||gradL(W)|| = 4.093389
# Iteration = 57, ||gradL(W)|| = 4.093389
# Iteration = 58, ||gradL(W)|| = 4.093389
# Iteration = 59, ||gradL(W)|| = 4.093389
# Iteration = 60, ||gradL(W)|| = 4.093389
# Iteration = 61, ||gradL(W)|| = 4.093389
# Iteration = 62, ||gradL(W)|| = 4.093389
# Iteration = 63, ||gradL(W)|| = 4.093389
# Iteration = 64, ||gradL(W)|| = 4.093389
# Iteration = 65, ||gradL(W)|| = 4.093389
# Iteration = 66, ||gradL(W)|| = 4.093389
# Iteration = 67, ||gradL(W)|| = 4.093389
# Iteration = 68, ||gradL(W)|| = 4.093389
# Iteration = 69, ||gradL(W)|| = 4.093389
# Iteration = 70, ||gradL(W)|| = 4.093389
# Iteration = 71, ||gradL(W)|| = 4.093389
# Iteration = 72, ||gradL(W)|| = 4.093389
# Iteration = 73, ||gradL(W)|| = 4.093389
# Iteration = 74, ||gradL(W)|| = 4.093389
# Iteration = 75, ||gradL(W)|| = 4.093389
# Iteration = 76, ||gradL(W)|| = 4.093389
# Iteration = 77, ||gradL(W)|| = 4.093389
# Iteration = 78, ||gradL(W)|| = 4.093389
# Iteration = 79, ||gradL(W)|| = 4.093389
# Iteration = 80, ||gradL(W)|| = 4.093389
# Iteration = 81, ||gradL(W)|| = 4.093389
# Iteration = 82, ||gradL(W)|| = 4.093389
# Iteration = 83, ||gradL(W)|| = 4.093389
# Iteration = 84, ||gradL(W)|| = 4.093389
# Iteration = 85, ||gradL(W)|| = 4.093389
# Iteration = 86, ||gradL(W)|| = 4.093389
# Iteration = 87, ||gradL(W)|| = 4.093389
# Iteration = 88, ||gradL(W)|| = 4.093389
# Iteration = 89, ||gradL(W)|| = 4.093389
# Iteration = 90, ||gradL(W)|| = 4.093389
# Iteration = 91, ||gradL(W)|| = 4.093389
# Iteration = 92, ||gradL(W)|| = 4.093389
# Iteration = 93, ||gradL(W)|| = 4.093389
# Iteration = 94, ||gradL(W)|| = 4.093389
# Iteration = 95, ||gradL(W)|| = 4.093389
# Iteration = 96, ||gradL(W)|| = 4.093389
# Iteration = 97, ||gradL(W)|| = 4.093389
# Iteration = 98, ||gradL(W)|| = 4.093389
# Iteration = 99, ||gradL(W)|| = 4.093389
# Iteration = 100, ||gradL(W)|| = 4.093389
# Iteration = 101, ||gradL(W)|| = 4.093389
# Iteration = 102, ||gradL(W)|| = 4.093389
# Iteration = 103, ||gradL(W)|| = 4.093389
# Iteration = 104, ||gradL(W)|| = 4.093389
# Iteration = 105, ||gradL(W)|| = 4.093389
# Iteration = 106, ||gradL(W)|| = 4.093389
# Iteration = 107, ||gradL(W)|| = 4.093389
# Iteration = 108, ||gradL(W)|| = 4.093389
# Iteration = 109, ||gradL(W)|| = 4.093389
# Iteration = 110, ||gradL(W)|| = 4.093389
# Iteration = 111, ||gradL(W)|| = 4.093389
# Iteration = 112, ||gradL(W)|| = 4.093389
# Iteration = 113, ||gradL(W)|| = 4.093389
# Iteration = 114, ||gradL(W)|| = 4.093389
# Iteration = 115, ||gradL(W)|| = 4.093389
# Iteration = 116, ||gradL(W)|| = 4.093389
# Iteration = 117, ||gradL(W)|| = 4.093389
# Iteration = 118, ||gradL(W)|| = 4.093389
# Iteration = 119, ||gradL(W)|| = 4.093389
# Iteration = 120, ||gradL(W)|| = 4.093389
# Iteration = 121, ||gradL(W)|| = 4.093389
# Iteration = 122, ||gradL(W)|| = 4.093389
# Iteration = 123, ||gradL(W)|| = 4.093389
# Iteration = 124, ||gradL(W)|| = 4.093389
# Iteration = 125, ||gradL(W)|| = 4.093389
# Iteration = 126, ||gradL(W)|| = 4.093389
# Iteration = 127, ||gradL(W)|| = 4.093389
# Iteration = 128, ||gradL(W)|| = 4.093389
# Iteration = 129, ||gradL(W)|| = 4.093389
# Iteration = 130, ||gradL(W)|| = 4.093389
# Iteration = 131, ||gradL(W)|| = 4.093389
# Iteration = 132, ||gradL(W)|| = 4.093389
# Iteration = 133, ||gradL(W)|| = 4.093389
# Iteration = 134, ||gradL(W)|| = 4.093389
# Iteration = 135, ||gradL(W)|| = 4.093389
# Iteration = 136, ||gradL(W)|| = 4.093389
# Iteration = 137, ||gradL(W)|| = 4.093389
# Iteration = 138, ||gradL(W)|| = 4.093389
# Iteration = 139, ||gradL(W)|| = 4.093389
# Iteration = 140, ||gradL(W)|| = 4.093389
# Iteration = 141, ||gradL(W)|| = 4.093389
# Iteration = 142, ||gradL(W)|| = 4.093389
# Iteration = 143, ||gradL(W)|| = 4.093389
# Iteration = 144, ||gradL(W)|| = 4.093389
# Iteration = 145, ||gradL(W)|| = 4.093389
# Iteration = 146, ||gradL(W)|| = 4.093389
# Iteration = 147, ||gradL(W)|| = 4.093389
# Iteration = 148, ||gradL(W)|| = 4.093389
# Iteration = 149, ||gradL(W)|| = 4.093389
# Iteration = 150, ||gradL(W)|| = 4.093389
# Iteration = 151, ||gradL(W)|| = 4.093389
# Iteration = 152, ||gradL(W)|| = 4.093389
# Iteration = 153, ||gradL(W)|| = 4.093389
# Iteration = 154, ||gradL(W)|| = 4.093389
# Iteration = 155, ||gradL(W)|| = 4.093389
# Iteration = 156, ||gradL(W)|| = 4.093389
# Iteration = 157, ||gradL(W)|| = 4.093389
# Iteration = 158, ||gradL(W)|| = 4.093389
# Iteration = 159, ||gradL(W)|| = 4.093389
# Iteration = 160, ||gradL(W)|| = 4.093389
# Iteration = 161, ||gradL(W)|| = 4.093389
# Iteration = 162, ||gradL(W)|| = 4.093389
# Iteration = 163, ||gradL(W)|| = 4.093389
# Iteration = 164, ||gradL(W)|| = 4.093389
# Iteration = 165, ||gradL(W)|| = 4.093389
# Iteration = 166, ||gradL(W)|| = 4.093389
# Iteration = 167, ||gradL(W)|| = 4.093389
# Iteration = 168, ||gradL(W)|| = 4.093389
# Iteration = 169, ||gradL(W)|| = 4.093389
# Iteration = 170, ||gradL(W)|| = 4.093389
# Iteration = 171, ||gradL(W)|| = 4.093389
# Iteration = 172, ||gradL(W)|| = 4.093389
# Iteration = 173, ||gradL(W)|| = 4.093389
# Iteration = 174, ||gradL(W)|| = 4.093389
# Iteration = 175, ||gradL(W)|| = 4.093389
# Iteration = 176, ||gradL(W)|| = 4.093389
# Iteration = 177, ||gradL(W)|| = 4.093389
# Iteration = 178, ||gradL(W)|| = 4.093389
# Iteration = 179, ||gradL(W)|| = 4.093389
# Iteration = 180, ||gradL(W)|| = 4.093389
# Iteration = 181, ||gradL(W)|| = 4.093389
# Iteration = 182, ||gradL(W)|| = 4.093389
# Iteration = 183, ||gradL(W)|| = 4.093389
# Iteration = 184, ||gradL(W)|| = 4.093389
# Iteration = 185, ||gradL(W)|| = 4.093389
# Iteration = 186, ||gradL(W)|| = 4.093389
# Iteration = 187, ||gradL(W)|| = 4.093389
# Iteration = 188, ||gradL(W)|| = 4.093389
# Iteration = 189, ||gradL(W)|| = 4.093389
# Iteration = 190, ||gradL(W)|| = 4.093389
# Iteration = 191, ||gradL(W)|| = 4.093389
# Iteration = 192, ||gradL(W)|| = 4.093389
# Iteration = 193, ||gradL(W)|| = 4.093389
# Iteration = 194, ||gradL(W)|| = 4.093389
# Iteration = 195, ||gradL(W)|| = 4.093389
# Iteration = 196, ||gradL(W)|| = 4.093389
# Iteration = 197, ||gradL(W)|| = 4.093389
# Iteration = 198, ||gradL(W)|| = 4.093389
# Iteration = 199, ||gradL(W)|| = 4.093389
# Iteration = 200, ||gradL(W)|| = 4.093389
# Iteration = 201, ||gradL(W)|| = 4.093389
# Iteration = 202, ||gradL(W)|| = 4.093389
# Iteration = 203, ||gradL(W)|| = 4.093389
# Iteration = 204, ||gradL(W)|| = 4.093389
# Iteration = 205, ||gradL(W)|| = 4.093389
# Iteration = 206, ||gradL(W)|| = 4.093389
# Iteration = 207, ||gradL(W)|| = 4.093389
# Iteration = 208, ||gradL(W)|| = 4.093389
# Iteration = 209, ||gradL(W)|| = 4.093389
# Iteration = 210, ||gradL(W)|| = 4.093389
# Iteration = 211, ||gradL(W)|| = 4.093389
# Iteration = 212, ||gradL(W)|| = 4.093389
# Iteration = 213, ||gradL(W)|| = 4.093389
# Iteration = 214, ||gradL(W)|| = 4.093389
# Iteration = 215, ||gradL(W)|| = 4.093389
# Iteration = 216, ||gradL(W)|| = 4.093389
# Iteration = 217, ||gradL(W)|| = 4.093389
# Iteration = 218, ||gradL(W)|| = 4.093389
# Iteration = 219, ||gradL(W)|| = 4.093389
# Iteration = 220, ||gradL(W)|| = 4.093389
# Iteration = 221, ||gradL(W)|| = 4.093389
# Iteration = 222, ||gradL(W)|| = 4.093389
# Iteration = 223, ||gradL(W)|| = 4.093389
# Iteration = 224, ||gradL(W)|| = 4.093389
# Iteration = 225, ||gradL(W)|| = 4.093389
# Iteration = 226, ||gradL(W)|| = 4.093389
# Iteration = 227, ||gradL(W)|| = 4.093389
# Iteration = 228, ||gradL(W)|| = 4.093389
# Iteration = 229, ||gradL(W)|| = 4.093389
# Iteration = 230, ||gradL(W)|| = 4.093389
# Iteration = 231, ||gradL(W)|| = 4.093389
# Iteration = 232, ||gradL(W)|| = 4.093389
# Iteration = 233, ||gradL(W)|| = 4.093389
# Iteration = 234, ||gradL(W)|| = 4.093389
# Iteration = 235, ||gradL(W)|| = 4.093389
# Iteration = 236, ||gradL(W)|| = 4.093389
# Iteration = 237, ||gradL(W)|| = 4.093389
# Iteration = 238, ||gradL(W)|| = 4.093389
# Iteration = 239, ||gradL(W)|| = 4.093389
# Iteration = 240, ||gradL(W)|| = 4.093389
# Iteration = 241, ||gradL(W)|| = 4.093389
# Iteration = 242, ||gradL(W)|| = 4.093389
# Iteration = 243, ||gradL(W)|| = 4.093389
# Iteration = 244, ||gradL(W)|| = 4.093389
# Iteration = 245, ||gradL(W)|| = 4.093389
# Iteration = 246, ||gradL(W)|| = 4.093389
# Iteration = 247, ||gradL(W)|| = 4.093389
# Iteration = 248, ||gradL(W)|| = 4.093389
# Iteration = 249, ||gradL(W)|| = 4.093389
# Iteration = 250, ||gradL(W)|| = 4.093389
# Iteration = 251, ||gradL(W)|| = 4.093389
# Iteration = 252, ||gradL(W)|| = 4.093389
# Iteration = 253, ||gradL(W)|| = 4.093389
# Iteration = 254, ||gradL(W)|| = 4.093389
# Iteration = 255, ||gradL(W)|| = 4.093389
# Iteration = 256, ||gradL(W)|| = 4.093389
# Iteration = 257, ||gradL(W)|| = 4.093389
# Iteration = 258, ||gradL(W)|| = 4.093389
# Iteration = 259, ||gradL(W)|| = 4.093389
# Iteration = 260, ||gradL(W)|| = 4.093389
# Iteration = 261, ||gradL(W)|| = 4.093389
# Iteration = 262, ||gradL(W)|| = 4.093389
# Iteration = 263, ||gradL(W)|| = 4.093389
# Iteration = 264, ||gradL(W)|| = 4.093389
# Iteration = 265, ||gradL(W)|| = 4.093389
# Iteration = 266, ||gradL(W)|| = 4.093389
# Iteration = 267, ||gradL(W)|| = 4.093389
# Iteration = 268, ||gradL(W)|| = 4.093389
# Iteration = 269, ||gradL(W)|| = 4.093389
# Iteration = 270, ||gradL(W)|| = 4.093389
# Iteration = 271, ||gradL(W)|| = 4.093389
# Iteration = 272, ||gradL(W)|| = 4.093389
# Iteration = 273, ||gradL(W)|| = 4.093389
# Iteration = 274, ||gradL(W)|| = 4.093389
# Iteration = 275, ||gradL(W)|| = 4.093389
# Iteration = 276, ||gradL(W)|| = 4.093389
# Iteration = 277, ||gradL(W)|| = 4.093389
# Iteration = 278, ||gradL(W)|| = 4.093389
# Iteration = 279, ||gradL(W)|| = 4.093389
# Iteration = 280, ||gradL(W)|| = 4.093389
# Iteration = 281, ||gradL(W)|| = 4.093389
# Iteration = 282, ||gradL(W)|| = 4.093389
# Iteration = 283, ||gradL(W)|| = 4.093389
# Iteration = 284, ||gradL(W)|| = 4.093389
# Iteration = 285, ||gradL(W)|| = 4.093389
# Iteration = 286, ||gradL(W)|| = 4.093389
# Iteration = 287, ||gradL(W)|| = 4.093389
# Iteration = 288, ||gradL(W)|| = 4.093389
# Iteration = 289, ||gradL(W)|| = 4.093389
# Iteration = 290, ||gradL(W)|| = 4.093389
# Iteration = 291, ||gradL(W)|| = 4.093389
# Iteration = 292, ||gradL(W)|| = 4.093389
# Iteration = 293, ||gradL(W)|| = 4.093389
# Iteration = 294, ||gradL(W)|| = 4.093389
# Iteration = 295, ||gradL(W)|| = 4.093389
# Iteration = 296, ||gradL(W)|| = 4.093389
# Iteration = 297, ||gradL(W)|| = 4.093389
# Iteration = 298, ||gradL(W)|| = 4.093389
# Iteration = 299, ||gradL(W)|| = 4.093389
# Iteration = 300, ||gradL(W)|| = 4.093389
# Iteration = 301, ||gradL(W)|| = 4.093389
# Iteration = 302, ||gradL(W)|| = 4.093389
# Iteration = 303, ||gradL(W)|| = 4.093389
# Iteration = 304, ||gradL(W)|| = 4.093389
# Iteration = 305, ||gradL(W)|| = 4.093389
# Iteration = 306, ||gradL(W)|| = 4.093389
# Iteration = 307, ||gradL(W)|| = 4.093389
# Iteration = 308, ||gradL(W)|| = 4.093389
# Iteration = 309, ||gradL(W)|| = 4.093389
# Iteration = 310, ||gradL(W)|| = 4.093389
# Iteration = 311, ||gradL(W)|| = 4.093389
# Iteration = 312, ||gradL(W)|| = 4.093389
# Iteration = 313, ||gradL(W)|| = 4.093389
# Iteration = 314, ||gradL(W)|| = 4.093389
# Iteration = 315, ||gradL(W)|| = 4.093389
# Iteration = 316, ||gradL(W)|| = 4.093389
# Iteration = 317, ||gradL(W)|| = 4.093389
# Iteration = 318, ||gradL(W)|| = 4.093389
# Iteration = 319, ||gradL(W)|| = 4.093389
# Iteration = 320, ||gradL(W)|| = 4.093389
# Iteration = 321, ||gradL(W)|| = 4.093389
# Iteration = 322, ||gradL(W)|| = 4.093389
# Iteration = 323, ||gradL(W)|| = 4.093389
# Iteration = 324, ||gradL(W)|| = 4.093389
# Iteration = 325, ||gradL(W)|| = 4.093389
# Iteration = 326, ||gradL(W)|| = 4.093389
# Iteration = 327, ||gradL(W)|| = 4.093389
# Iteration = 328, ||gradL(W)|| = 4.093389
# Iteration = 329, ||gradL(W)|| = 4.093389
# Iteration = 330, ||gradL(W)|| = 4.093389
# Iteration = 331, ||gradL(W)|| = 4.093389
# Iteration = 332, ||gradL(W)|| = 4.093389
# Iteration = 333, ||gradL(W)|| = 4.093389
# Iteration = 334, ||gradL(W)|| = 4.093389
# Iteration = 335, ||gradL(W)|| = 4.093389
# Iteration = 336, ||gradL(W)|| = 4.093389
# Iteration = 337, ||gradL(W)|| = 4.093389
# Iteration = 338, ||gradL(W)|| = 4.093389
# Iteration = 339, ||gradL(W)|| = 4.093389
# Iteration = 340, ||gradL(W)|| = 4.093389
# Iteration = 341, ||gradL(W)|| = 4.093389
# Iteration = 342, ||gradL(W)|| = 4.093389
# Iteration = 343, ||gradL(W)|| = 4.093389
# Iteration = 344, ||gradL(W)|| = 4.093389
# Iteration = 345, ||gradL(W)|| = 4.093389
# Iteration = 346, ||gradL(W)|| = 4.093389
# Iteration = 347, ||gradL(W)|| = 4.093389
# Iteration = 348, ||gradL(W)|| = 4.093389
# Iteration = 349, ||gradL(W)|| = 4.093389
# Iteration = 350, ||gradL(W)|| = 4.093389
# Iteration = 351, ||gradL(W)|| = 4.093389
# Iteration = 352, ||gradL(W)|| = 4.093389
# Iteration = 353, ||gradL(W)|| = 4.093389
# Iteration = 354, ||gradL(W)|| = 4.093389
# Iteration = 355, ||gradL(W)|| = 4.093389
# Iteration = 356, ||gradL(W)|| = 4.093389
# Iteration = 357, ||gradL(W)|| = 4.093389
# Iteration = 358, ||gradL(W)|| = 4.093389
# Iteration = 359, ||gradL(W)|| = 4.093389
# Iteration = 360, ||gradL(W)|| = 4.093389
# Iteration = 361, ||gradL(W)|| = 4.093389
# Iteration = 362, ||gradL(W)|| = 4.093389
# Iteration = 363, ||gradL(W)|| = 4.093389
# Iteration = 364, ||gradL(W)|| = 4.093389
# Iteration = 365, ||gradL(W)|| = 4.093389
# Iteration = 366, ||gradL(W)|| = 4.093389
# Iteration = 367, ||gradL(W)|| = 4.093389
# Iteration = 368, ||gradL(W)|| = 4.093389
# Iteration = 369, ||gradL(W)|| = 4.093389
# Iteration = 370, ||gradL(W)|| = 4.093389
# Iteration = 371, ||gradL(W)|| = 4.093389
# Iteration = 372, ||gradL(W)|| = 4.093389
# Iteration = 373, ||gradL(W)|| = 4.093389
# Iteration = 374, ||gradL(W)|| = 4.093389
# Iteration = 375, ||gradL(W)|| = 4.093389
# Iteration = 376, ||gradL(W)|| = 4.093389
# Iteration = 377, ||gradL(W)|| = 4.093389
# Iteration = 378, ||gradL(W)|| = 4.093389
# Iteration = 379, ||gradL(W)|| = 4.093389
# Iteration = 380, ||gradL(W)|| = 4.093389
# Iteration = 381, ||gradL(W)|| = 4.093389
# Iteration = 382, ||gradL(W)|| = 4.093389
# Iteration = 383, ||gradL(W)|| = 4.093389
# Iteration = 384, ||gradL(W)|| = 4.093389
# Iteration = 385, ||gradL(W)|| = 4.093389
# Iteration = 386, ||gradL(W)|| = 4.093389
# Iteration = 387, ||gradL(W)|| = 4.093389
# Iteration = 388, ||gradL(W)|| = 4.093389
# Iteration = 389, ||gradL(W)|| = 4.093389
# Iteration = 390, ||gradL(W)|| = 4.093389
# Iteration = 391, ||gradL(W)|| = 4.093389
# Iteration = 392, ||gradL(W)|| = 4.093389
# Iteration = 393, ||gradL(W)|| = 4.093389
# Iteration = 394, ||gradL(W)|| = 4.093389
# Iteration = 395, ||gradL(W)|| = 4.093389
# Iteration = 396, ||gradL(W)|| = 4.093389
# Iteration = 397, ||gradL(W)|| = 4.093389
# Iteration = 398, ||gradL(W)|| = 4.093389
# Iteration = 399, ||gradL(W)|| = 4.093389
# Iteration = 400, ||gradL(W)|| = 4.093389
# Iteration = 401, ||gradL(W)|| = 4.093389
# Iteration = 402, ||gradL(W)|| = 4.093389
# Iteration = 403, ||gradL(W)|| = 4.093389
# Iteration = 404, ||gradL(W)|| = 4.093389
# Iteration = 405, ||gradL(W)|| = 4.093389
# Iteration = 406, ||gradL(W)|| = 4.093389
# Iteration = 407, ||gradL(W)|| = 4.093389
# Iteration = 408, ||gradL(W)|| = 4.093389
# Iteration = 409, ||gradL(W)|| = 4.093389
# Iteration = 410, ||gradL(W)|| = 4.093389
# Iteration = 411, ||gradL(W)|| = 4.093389
# Iteration = 412, ||gradL(W)|| = 4.093389
# Iteration = 413, ||gradL(W)|| = 4.093389
# Iteration = 414, ||gradL(W)|| = 4.093389
# Iteration = 415, ||gradL(W)|| = 4.093389
# Iteration = 416, ||gradL(W)|| = 4.093389
# Iteration = 417, ||gradL(W)|| = 4.093389
# Iteration = 418, ||gradL(W)|| = 4.093389
# Iteration = 419, ||gradL(W)|| = 4.093389
# Iteration = 420, ||gradL(W)|| = 4.093389
# Iteration = 421, ||gradL(W)|| = 4.093389
# Iteration = 422, ||gradL(W)|| = 4.093389
# Iteration = 423, ||gradL(W)|| = 4.093389
# Iteration = 424, ||gradL(W)|| = 4.093389
# Iteration = 425, ||gradL(W)|| = 4.093389
# Iteration = 426, ||gradL(W)|| = 4.093389
# Iteration = 427, ||gradL(W)|| = 4.093389
# Iteration = 428, ||gradL(W)|| = 4.093389
# Iteration = 429, ||gradL(W)|| = 4.093389
# Iteration = 430, ||gradL(W)|| = 4.093389
# Iteration = 431, ||gradL(W)|| = 4.093389
# Iteration = 432, ||gradL(W)|| = 4.093389
# Iteration = 433, ||gradL(W)|| = 4.093389
# Iteration = 434, ||gradL(W)|| = 4.093389
# Iteration = 435, ||gradL(W)|| = 4.093389
# Iteration = 436, ||gradL(W)|| = 4.093389
# Iteration = 437, ||gradL(W)|| = 4.093389
# Iteration = 438, ||gradL(W)|| = 4.093389
# Iteration = 439, ||gradL(W)|| = 4.093389
# Iteration = 440, ||gradL(W)|| = 4.093389
# Iteration = 441, ||gradL(W)|| = 4.093389
# Iteration = 442, ||gradL(W)|| = 4.093389
# Iteration = 443, ||gradL(W)|| = 4.093389
# Iteration = 444, ||gradL(W)|| = 4.093389
# Iteration = 445, ||gradL(W)|| = 4.093389
# Iteration = 446, ||gradL(W)|| = 4.093389
# Iteration = 447, ||gradL(W)|| = 4.093389
# Iteration = 448, ||gradL(W)|| = 4.093389
# Iteration = 449, ||gradL(W)|| = 4.093389
# Iteration = 450, ||gradL(W)|| = 4.093389
# Iteration = 451, ||gradL(W)|| = 4.093389
# Iteration = 452, ||gradL(W)|| = 4.093389
# Iteration = 453, ||gradL(W)|| = 4.093389
# Iteration = 454, ||gradL(W)|| = 4.093389
# Iteration = 455, ||gradL(W)|| = 4.093389
# Iteration = 456, ||gradL(W)|| = 4.093389
# Iteration = 457, ||gradL(W)|| = 4.093389
# Iteration = 458, ||gradL(W)|| = 4.093389
# Iteration = 459, ||gradL(W)|| = 4.093389
# Iteration = 460, ||gradL(W)|| = 4.093389
# Iteration = 461, ||gradL(W)|| = 4.093389
# Iteration = 462, ||gradL(W)|| = 4.093389
# Iteration = 463, ||gradL(W)|| = 4.093389
# Iteration = 464, ||gradL(W)|| = 4.093389
# Iteration = 465, ||gradL(W)|| = 4.093389
# Iteration = 466, ||gradL(W)|| = 4.093389
# Iteration = 467, ||gradL(W)|| = 4.093389
# Iteration = 468, ||gradL(W)|| = 4.093389
# Iteration = 469, ||gradL(W)|| = 4.093389
# Iteration = 470, ||gradL(W)|| = 4.093389
# Iteration = 471, ||gradL(W)|| = 4.093389
# Iteration = 472, ||gradL(W)|| = 4.093389
# Iteration = 473, ||gradL(W)|| = 4.093389
# Iteration = 474, ||gradL(W)|| = 4.093389
# Iteration = 475, ||gradL(W)|| = 4.093389
# Iteration = 476, ||gradL(W)|| = 4.093389
# Iteration = 477, ||gradL(W)|| = 4.093389
# Iteration = 478, ||gradL(W)|| = 4.093389
# Iteration = 479, ||gradL(W)|| = 4.093389
# Iteration = 480, ||gradL(W)|| = 4.093389
# Iteration = 481, ||gradL(W)|| = 4.093389
# Iteration = 482, ||gradL(W)|| = 4.093389
# Iteration = 483, ||gradL(W)|| = 4.093389
# Iteration = 484, ||gradL(W)|| = 4.093389
# Iteration = 485, ||gradL(W)|| = 4.093389
# Iteration = 486, ||gradL(W)|| = 4.093389
# Iteration = 487, ||gradL(W)|| = 4.093389
# Iteration = 488, ||gradL(W)|| = 4.093389
# Iteration = 489, ||gradL(W)|| = 4.093389
# Iteration = 490, ||gradL(W)|| = 4.093389
# Iteration = 491, ||gradL(W)|| = 4.093389
# Iteration = 492, ||gradL(W)|| = 4.093389
# Iteration = 493, ||gradL(W)|| = 4.093389
# Iteration = 494, ||gradL(W)|| = 4.093389
# Iteration = 495, ||gradL(W)|| = 4.093389
# Iteration = 496, ||gradL(W)|| = 4.093389
# Iteration = 497, ||gradL(W)|| = 4.093389
# Iteration = 498, ||gradL(W)|| = 4.093389
# Iteration = 499, ||gradL(W)|| = 4.093389
# Iteration = 500, ||gradL(W)|| = 4.093389
# Iteration = 501, ||gradL(W)|| = 4.093389
# Iteration = 502, ||gradL(W)|| = 4.093389
# Iteration = 503, ||gradL(W)|| = 4.093389
# Iteration = 504, ||gradL(W)|| = 4.093389
# Iteration = 505, ||gradL(W)|| = 4.093389
# Iteration = 506, ||gradL(W)|| = 4.093389
# Iteration = 507, ||gradL(W)|| = 4.093389
# Iteration = 508, ||gradL(W)|| = 4.093389
# Iteration = 509, ||gradL(W)|| = 4.093389
# Iteration = 510, ||gradL(W)|| = 4.093389
# Iteration = 511, ||gradL(W)|| = 4.093389
# Iteration = 512, ||gradL(W)|| = 4.093389
# Iteration = 513, ||gradL(W)|| = 4.093389
# Iteration = 514, ||gradL(W)|| = 4.093389
# Iteration = 515, ||gradL(W)|| = 4.093389
# Iteration = 516, ||gradL(W)|| = 4.093389
# Iteration = 517, ||gradL(W)|| = 4.093389
# Iteration = 518, ||gradL(W)|| = 4.093389
# Iteration = 519, ||gradL(W)|| = 4.093389
# Iteration = 520, ||gradL(W)|| = 4.093389
# Iteration = 521, ||gradL(W)|| = 4.093389
# Iteration = 522, ||gradL(W)|| = 4.093389
# Iteration = 523, ||gradL(W)|| = 4.093389
# Iteration = 524, ||gradL(W)|| = 4.093389
# Iteration = 525, ||gradL(W)|| = 4.093389
# Iteration = 526, ||gradL(W)|| = 4.093389
# Iteration = 527, ||gradL(W)|| = 4.093389
# Iteration = 528, ||gradL(W)|| = 4.093389
# Iteration = 529, ||gradL(W)|| = 4.093389
# Iteration = 530, ||gradL(W)|| = 4.093389
# Iteration = 531, ||gradL(W)|| = 4.093389
# Iteration = 532, ||gradL(W)|| = 4.093389
# Iteration = 533, ||gradL(W)|| = 4.093389
# Iteration = 534, ||gradL(W)|| = 4.093389
# Iteration = 535, ||gradL(W)|| = 4.093389
# Iteration = 536, ||gradL(W)|| = 4.093389
# Iteration = 537, ||gradL(W)|| = 4.093389
# Iteration = 538, ||gradL(W)|| = 4.093389
# Iteration = 539, ||gradL(W)|| = 4.093389
# Iteration = 540, ||gradL(W)|| = 4.093389
# Iteration = 541, ||gradL(W)|| = 4.093389
# Iteration = 542, ||gradL(W)|| = 4.093389
# Iteration = 543, ||gradL(W)|| = 4.093389
# Iteration = 544, ||gradL(W)|| = 4.093389
# Iteration = 545, ||gradL(W)|| = 4.093389
# Iteration = 546, ||gradL(W)|| = 4.093389
# Iteration = 547, ||gradL(W)|| = 4.093389
# Iteration = 548, ||gradL(W)|| = 4.093389
# Iteration = 549, ||gradL(W)|| = 4.093389
# Iteration = 550, ||gradL(W)|| = 4.093389
# Iteration = 551, ||gradL(W)|| = 4.093389
# Iteration = 552, ||gradL(W)|| = 4.093389
# Iteration = 553, ||gradL(W)|| = 4.093389
# Iteration = 554, ||gradL(W)|| = 4.093389
# Iteration = 555, ||gradL(W)|| = 4.093389
# Iteration = 556, ||gradL(W)|| = 4.093389
# Iteration = 557, ||gradL(W)|| = 4.093389
# Iteration = 558, ||gradL(W)|| = 4.093389
# Iteration = 559, ||gradL(W)|| = 4.093389
# Iteration = 560, ||gradL(W)|| = 4.093389
# Iteration = 561, ||gradL(W)|| = 4.093389
# Iteration = 562, ||gradL(W)|| = 4.093389
# Iteration = 563, ||gradL(W)|| = 4.093389
# Iteration = 564, ||gradL(W)|| = 4.093389
# Iteration = 565, ||gradL(W)|| = 4.093389
# Iteration = 566, ||gradL(W)|| = 4.093389
# Iteration = 567, ||gradL(W)|| = 4.093389
# Iteration = 568, ||gradL(W)|| = 4.093389
# Iteration = 569, ||gradL(W)|| = 4.093389
# Iteration = 570, ||gradL(W)|| = 4.093389
# Iteration = 571, ||gradL(W)|| = 4.093389
# Iteration = 572, ||gradL(W)|| = 4.093389
# Iteration = 573, ||gradL(W)|| = 4.093389
# Iteration = 574, ||gradL(W)|| = 4.093389
# Iteration = 575, ||gradL(W)|| = 4.093389
# Iteration = 576, ||gradL(W)|| = 4.093389
# Iteration = 577, ||gradL(W)|| = 4.093389
# Iteration = 578, ||gradL(W)|| = 4.093389
# Iteration = 579, ||gradL(W)|| = 4.093389
# Iteration = 580, ||gradL(W)|| = 4.093389
# Iteration = 581, ||gradL(W)|| = 4.093389
# Iteration = 582, ||gradL(W)|| = 4.093389
# Iteration = 583, ||gradL(W)|| = 4.093389
# Iteration = 584, ||gradL(W)|| = 4.093389
# Iteration = 585, ||gradL(W)|| = 4.093389
# Iteration = 586, ||gradL(W)|| = 4.093389
# Iteration = 587, ||gradL(W)|| = 4.093389
# Iteration = 588, ||gradL(W)|| = 4.093389
# Iteration = 589, ||gradL(W)|| = 4.093389
# Iteration = 590, ||gradL(W)|| = 4.093389
# Iteration = 591, ||gradL(W)|| = 4.093389
# Iteration = 592, ||gradL(W)|| = 4.093389
# Iteration = 593, ||gradL(W)|| = 4.093389
# Iteration = 594, ||gradL(W)|| = 4.093389
# Iteration = 595, ||gradL(W)|| = 4.093389
# Iteration = 596, ||gradL(W)|| = 4.093389
# Iteration = 597, ||gradL(W)|| = 4.093389
# Iteration = 598, ||gradL(W)|| = 4.093389
# Iteration = 599, ||gradL(W)|| = 4.093389
# Iteration = 600, ||gradL(W)|| = 4.093389
# Iteration = 601, ||gradL(W)|| = 4.093389
# Iteration = 602, ||gradL(W)|| = 4.093389
# Iteration = 603, ||gradL(W)|| = 4.093389
# Iteration = 604, ||gradL(W)|| = 4.093389
# Iteration = 605, ||gradL(W)|| = 4.093389
# Iteration = 606, ||gradL(W)|| = 4.093389
# Iteration = 607, ||gradL(W)|| = 4.093389
# Iteration = 608, ||gradL(W)|| = 4.093389
# Iteration = 609, ||gradL(W)|| = 4.093389
# Iteration = 610, ||gradL(W)|| = 4.093389
# Iteration = 611, ||gradL(W)|| = 4.093389
# Iteration = 612, ||gradL(W)|| = 4.093389
# Iteration = 613, ||gradL(W)|| = 4.093389
# Iteration = 614, ||gradL(W)|| = 4.093389
# Iteration = 615, ||gradL(W)|| = 4.093389
# Iteration = 616, ||gradL(W)|| = 4.093389
# Iteration = 617, ||gradL(W)|| = 4.093389
# Iteration = 618, ||gradL(W)|| = 4.093389
# Iteration = 619, ||gradL(W)|| = 4.093389
# Iteration = 620, ||gradL(W)|| = 4.093389
# Iteration = 621, ||gradL(W)|| = 4.093389
# Iteration = 622, ||gradL(W)|| = 4.093389
# Iteration = 623, ||gradL(W)|| = 4.093389
# Iteration = 624, ||gradL(W)|| = 4.093389
# Iteration = 625, ||gradL(W)|| = 4.093389
# Iteration = 626, ||gradL(W)|| = 4.093389
# Iteration = 627, ||gradL(W)|| = 4.093389
# Iteration = 628, ||gradL(W)|| = 4.093389
# Iteration = 629, ||gradL(W)|| = 4.093389
# Iteration = 630, ||gradL(W)|| = 4.093389
# Iteration = 631, ||gradL(W)|| = 4.093389
# Iteration = 632, ||gradL(W)|| = 4.093389
# Iteration = 633, ||gradL(W)|| = 4.093389
# Iteration = 634, ||gradL(W)|| = 4.093389
# Iteration = 635, ||gradL(W)|| = 4.093389
# Iteration = 636, ||gradL(W)|| = 4.093389
# Iteration = 637, ||gradL(W)|| = 4.093389
# Iteration = 638, ||gradL(W)|| = 4.093389
# Iteration = 639, ||gradL(W)|| = 4.093389
# Iteration = 640, ||gradL(W)|| = 4.093389
# Iteration = 641, ||gradL(W)|| = 4.093389
# Iteration = 642, ||gradL(W)|| = 4.093389
# Iteration = 643, ||gradL(W)|| = 4.093389
# Iteration = 644, ||gradL(W)|| = 4.093389
# Iteration = 645, ||gradL(W)|| = 4.093389
# Iteration = 646, ||gradL(W)|| = 4.093389
# Iteration = 647, ||gradL(W)|| = 4.093389
# Iteration = 648, ||gradL(W)|| = 4.093389
# Iteration = 649, ||gradL(W)|| = 4.093389
# Iteration = 650, ||gradL(W)|| = 4.093389
# Iteration = 651, ||gradL(W)|| = 4.093389
# Iteration = 652, ||gradL(W)|| = 4.093389
# Iteration = 653, ||gradL(W)|| = 4.093389
# Iteration = 654, ||gradL(W)|| = 4.093389
# Iteration = 655, ||gradL(W)|| = 4.093389
# Iteration = 656, ||gradL(W)|| = 4.093389
# Iteration = 657, ||gradL(W)|| = 4.093389
# Iteration = 658, ||gradL(W)|| = 4.093389
# Iteration = 659, ||gradL(W)|| = 4.093389
# Iteration = 660, ||gradL(W)|| = 4.093389
# Iteration = 661, ||gradL(W)|| = 4.093389
# Iteration = 662, ||gradL(W)|| = 4.093389
# Iteration = 663, ||gradL(W)|| = 4.093389
# Iteration = 664, ||gradL(W)|| = 4.093389
# Iteration = 665, ||gradL(W)|| = 4.093389
# Iteration = 666, ||gradL(W)|| = 4.093389
# Iteration = 667, ||gradL(W)|| = 4.093389
# Iteration = 668, ||gradL(W)|| = 4.093389
# Iteration = 669, ||gradL(W)|| = 4.093389
# Iteration = 670, ||gradL(W)|| = 4.093389
# Iteration = 671, ||gradL(W)|| = 4.093389
# Iteration = 672, ||gradL(W)|| = 4.093389
# Iteration = 673, ||gradL(W)|| = 4.093389
# Iteration = 674, ||gradL(W)|| = 4.093389
# Iteration = 675, ||gradL(W)|| = 4.093389
# Iteration = 676, ||gradL(W)|| = 4.093389
# Iteration = 677, ||gradL(W)|| = 4.093389
# Iteration = 678, ||gradL(W)|| = 4.093389
# Iteration = 679, ||gradL(W)|| = 4.093389
# Iteration = 680, ||gradL(W)|| = 4.093389
# Iteration = 681, ||gradL(W)|| = 4.093389
# Iteration = 682, ||gradL(W)|| = 4.093389
# Iteration = 683, ||gradL(W)|| = 4.093389
# Iteration = 684, ||gradL(W)|| = 4.093389
# Iteration = 685, ||gradL(W)|| = 4.093389
# Iteration = 686, ||gradL(W)|| = 4.093389
# Iteration = 687, ||gradL(W)|| = 4.093389
# Iteration = 688, ||gradL(W)|| = 4.093389
# Iteration = 689, ||gradL(W)|| = 4.093389
# Iteration = 690, ||gradL(W)|| = 4.093389
# Iteration = 691, ||gradL(W)|| = 4.093389
# Iteration = 692, ||gradL(W)|| = 4.093389
# Iteration = 693, ||gradL(W)|| = 4.093389
# Iteration = 694, ||gradL(W)|| = 4.093389
# Iteration = 695, ||gradL(W)|| = 4.093389
# Iteration = 696, ||gradL(W)|| = 4.093389
# Iteration = 697, ||gradL(W)|| = 4.093389
# Iteration = 698, ||gradL(W)|| = 4.093389
# Iteration = 699, ||gradL(W)|| = 4.093389
# Iteration = 700, ||gradL(W)|| = 4.093389
# Iteration = 701, ||gradL(W)|| = 4.093389
# Iteration = 702, ||gradL(W)|| = 4.093389
# Iteration = 703, ||gradL(W)|| = 4.093389
# Iteration = 704, ||gradL(W)|| = 4.093389
# Iteration = 705, ||gradL(W)|| = 4.093389
# Iteration = 706, ||gradL(W)|| = 4.093389
# Iteration = 707, ||gradL(W)|| = 4.093389
# Iteration = 708, ||gradL(W)|| = 4.093389
# Iteration = 709, ||gradL(W)|| = 4.093389
# Iteration = 710, ||gradL(W)|| = 4.093389
# Iteration = 711, ||gradL(W)|| = 4.093389
# Iteration = 712, ||gradL(W)|| = 4.093389
# Iteration = 713, ||gradL(W)|| = 4.093389
# Iteration = 714, ||gradL(W)|| = 4.093389
# Iteration = 715, ||gradL(W)|| = 4.093389
# Iteration = 716, ||gradL(W)|| = 4.093389
# Iteration = 717, ||gradL(W)|| = 4.093389
# Iteration = 718, ||gradL(W)|| = 4.093389
# Iteration = 719, ||gradL(W)|| = 4.093389
# Iteration = 720, ||gradL(W)|| = 4.093389
# Iteration = 721, ||gradL(W)|| = 4.093389
# Iteration = 722, ||gradL(W)|| = 4.093389
# Iteration = 723, ||gradL(W)|| = 4.093389
# Iteration = 724, ||gradL(W)|| = 4.093389
# Iteration = 725, ||gradL(W)|| = 4.093389
# Iteration = 726, ||gradL(W)|| = 4.093389
# Iteration = 727, ||gradL(W)|| = 4.093389
# Iteration = 728, ||gradL(W)|| = 4.093389
# Iteration = 729, ||gradL(W)|| = 4.093389
# Iteration = 730, ||gradL(W)|| = 4.093389
# Iteration = 731, ||gradL(W)|| = 4.093389
# Iteration = 732, ||gradL(W)|| = 4.093389
# Iteration = 733, ||gradL(W)|| = 4.093389
# Iteration = 734, ||gradL(W)|| = 4.093389
# Iteration = 735, ||gradL(W)|| = 4.093389
# Iteration = 736, ||gradL(W)|| = 4.093389
# Iteration = 737, ||gradL(W)|| = 4.093389
# Iteration = 738, ||gradL(W)|| = 4.093389
# Iteration = 739, ||gradL(W)|| = 4.093389
# Iteration = 740, ||gradL(W)|| = 4.093389
# Iteration = 741, ||gradL(W)|| = 4.093389
# Iteration = 742, ||gradL(W)|| = 4.093389
# Iteration = 743, ||gradL(W)|| = 4.093389
# Iteration = 744, ||gradL(W)|| = 4.093389
# Iteration = 745, ||gradL(W)|| = 4.093389
# Iteration = 746, ||gradL(W)|| = 4.093389
# Iteration = 747, ||gradL(W)|| = 4.093389
# Iteration = 748, ||gradL(W)|| = 4.093389
# Iteration = 749, ||gradL(W)|| = 4.093389
# Iteration = 750, ||gradL(W)|| = 4.093389
# Iteration = 751, ||gradL(W)|| = 4.093389
# Iteration = 752, ||gradL(W)|| = 4.093389
# Iteration = 753, ||gradL(W)|| = 4.093389
# Iteration = 754, ||gradL(W)|| = 4.093389
# Iteration = 755, ||gradL(W)|| = 4.093389
# Iteration = 756, ||gradL(W)|| = 4.093389
# Iteration = 757, ||gradL(W)|| = 4.093389
# Iteration = 758, ||gradL(W)|| = 4.093389
# Iteration = 759, ||gradL(W)|| = 4.093389
# Iteration = 760, ||gradL(W)|| = 4.093389
# Iteration = 761, ||gradL(W)|| = 4.093389
# Iteration = 762, ||gradL(W)|| = 4.093389
# Iteration = 763, ||gradL(W)|| = 4.093389
# Iteration = 764, ||gradL(W)|| = 4.093389
# Iteration = 765, ||gradL(W)|| = 4.093389
# Iteration = 766, ||gradL(W)|| = 4.093389
# Iteration = 767, ||gradL(W)|| = 4.093389
# Iteration = 768, ||gradL(W)|| = 4.093389
# Iteration = 769, ||gradL(W)|| = 4.093389
# Iteration = 770, ||gradL(W)|| = 4.093389
# Iteration = 771, ||gradL(W)|| = 4.093389
# Iteration = 772, ||gradL(W)|| = 4.093389
# Iteration = 773, ||gradL(W)|| = 4.093389
# Iteration = 774, ||gradL(W)|| = 4.093389
# Iteration = 775, ||gradL(W)|| = 4.093389
# Iteration = 776, ||gradL(W)|| = 4.093389
# Iteration = 777, ||gradL(W)|| = 4.093389
# Iteration = 778, ||gradL(W)|| = 4.093389
# Iteration = 779, ||gradL(W)|| = 4.093389
# Iteration = 780, ||gradL(W)|| = 4.093389
# Iteration = 781, ||gradL(W)|| = 4.093389
# Iteration = 782, ||gradL(W)|| = 4.093389
# Iteration = 783, ||gradL(W)|| = 4.093389
# Iteration = 784, ||gradL(W)|| = 4.093389
# Iteration = 785, ||gradL(W)|| = 4.093389
# Iteration = 786, ||gradL(W)|| = 4.093389
# Iteration = 787, ||gradL(W)|| = 4.093389
# Iteration = 788, ||gradL(W)|| = 4.093389
# Iteration = 789, ||gradL(W)|| = 4.093389
# Iteration = 790, ||gradL(W)|| = 4.093389
# Iteration = 791, ||gradL(W)|| = 4.093389
# Iteration = 792, ||gradL(W)|| = 4.093389
# Iteration = 793, ||gradL(W)|| = 4.093389
# Iteration = 794, ||gradL(W)|| = 4.093389
# Iteration = 795, ||gradL(W)|| = 4.093389
# Iteration = 796, ||gradL(W)|| = 4.093389
# Iteration = 797, ||gradL(W)|| = 4.093389
# Iteration = 798, ||gradL(W)|| = 4.093389
# Iteration = 799, ||gradL(W)|| = 4.093389
# Iteration = 800, ||gradL(W)|| = 4.093389
# Iteration = 801, ||gradL(W)|| = 4.093389
# Iteration = 802, ||gradL(W)|| = 4.093389
# Iteration = 803, ||gradL(W)|| = 4.093389
# Iteration = 804, ||gradL(W)|| = 4.093389
# Iteration = 805, ||gradL(W)|| = 4.093389
# Iteration = 806, ||gradL(W)|| = 4.093389
# Iteration = 807, ||gradL(W)|| = 4.093389
# Iteration = 808, ||gradL(W)|| = 4.093389
# Iteration = 809, ||gradL(W)|| = 4.093389
# Iteration = 810, ||gradL(W)|| = 4.093389
# Iteration = 811, ||gradL(W)|| = 4.093389
# Iteration = 812, ||gradL(W)|| = 4.093389
# Iteration = 813, ||gradL(W)|| = 4.093389
# Iteration = 814, ||gradL(W)|| = 4.093389
# Iteration = 815, ||gradL(W)|| = 4.093389
# Iteration = 816, ||gradL(W)|| = 4.093389
# Iteration = 817, ||gradL(W)|| = 4.093389
# Iteration = 818, ||gradL(W)|| = 4.093389
# Iteration = 819, ||gradL(W)|| = 4.093389
# Iteration = 820, ||gradL(W)|| = 4.093389
# Iteration = 821, ||gradL(W)|| = 4.093389
# Iteration = 822, ||gradL(W)|| = 4.093389
# Iteration = 823, ||gradL(W)|| = 4.093389
# Iteration = 824, ||gradL(W)|| = 4.093389
# Iteration = 825, ||gradL(W)|| = 4.093389
# Iteration = 826, ||gradL(W)|| = 4.093389
# Iteration = 827, ||gradL(W)|| = 4.093389
# Iteration = 828, ||gradL(W)|| = 4.093389
# Iteration = 829, ||gradL(W)|| = 4.093389
# Iteration = 830, ||gradL(W)|| = 4.093389
# Iteration = 831, ||gradL(W)|| = 4.093389
# Iteration = 832, ||gradL(W)|| = 4.093389
# Iteration = 833, ||gradL(W)|| = 4.093389
# Iteration = 834, ||gradL(W)|| = 4.093389
# Iteration = 835, ||gradL(W)|| = 4.093389
# Iteration = 836, ||gradL(W)|| = 4.093389
# Iteration = 837, ||gradL(W)|| = 4.093389
# Iteration = 838, ||gradL(W)|| = 4.093389
# Iteration = 839, ||gradL(W)|| = 4.093389
# Iteration = 840, ||gradL(W)|| = 4.093389
# Iteration = 841, ||gradL(W)|| = 4.093389
# Iteration = 842, ||gradL(W)|| = 4.093389
# Iteration = 843, ||gradL(W)|| = 4.093389
# Iteration = 844, ||gradL(W)|| = 4.093389
# Iteration = 845, ||gradL(W)|| = 4.093389
# Iteration = 846, ||gradL(W)|| = 4.093389
# Iteration = 847, ||gradL(W)|| = 4.093389
# Iteration = 848, ||gradL(W)|| = 4.093389
# Iteration = 849, ||gradL(W)|| = 4.093389
# Iteration = 850, ||gradL(W)|| = 4.093389
# Iteration = 851, ||gradL(W)|| = 4.093389
# Iteration = 852, ||gradL(W)|| = 4.093389
# Iteration = 853, ||gradL(W)|| = 4.093389
# Iteration = 854, ||gradL(W)|| = 4.093389
# Iteration = 855, ||gradL(W)|| = 4.093389
# Iteration = 856, ||gradL(W)|| = 4.093389
# Iteration = 857, ||gradL(W)|| = 4.093389
# Iteration = 858, ||gradL(W)|| = 4.093389
# Iteration = 859, ||gradL(W)|| = 4.093389
# Iteration = 860, ||gradL(W)|| = 4.093389
# Iteration = 861, ||gradL(W)|| = 4.093389
# Iteration = 862, ||gradL(W)|| = 4.093389
# Iteration = 863, ||gradL(W)|| = 4.093389
# Iteration = 864, ||gradL(W)|| = 4.093389
# Iteration = 865, ||gradL(W)|| = 4.093389
# Iteration = 866, ||gradL(W)|| = 4.093389
# Iteration = 867, ||gradL(W)|| = 4.093389
# Iteration = 868, ||gradL(W)|| = 4.093389
# Iteration = 869, ||gradL(W)|| = 4.093389
# Iteration = 870, ||gradL(W)|| = 4.093389
# Iteration = 871, ||gradL(W)|| = 4.093389
# Iteration = 872, ||gradL(W)|| = 4.093389
# Iteration = 873, ||gradL(W)|| = 4.093389
# Iteration = 874, ||gradL(W)|| = 4.093389
# Iteration = 875, ||gradL(W)|| = 4.093389
# Iteration = 876, ||gradL(W)|| = 4.093389
# Iteration = 877, ||gradL(W)|| = 4.093389
# Iteration = 878, ||gradL(W)|| = 4.093389
# Iteration = 879, ||gradL(W)|| = 4.093389
# Iteration = 880, ||gradL(W)|| = 4.093389
# Iteration = 881, ||gradL(W)|| = 4.093389
# Iteration = 882, ||gradL(W)|| = 4.093389
# Iteration = 883, ||gradL(W)|| = 4.093389
# Iteration = 884, ||gradL(W)|| = 4.093389
# Iteration = 885, ||gradL(W)|| = 4.093389
# Iteration = 886, ||gradL(W)|| = 4.093389
# Iteration = 887, ||gradL(W)|| = 4.093389
# Iteration = 888, ||gradL(W)|| = 4.093389
# Iteration = 889, ||gradL(W)|| = 4.093389
# Iteration = 890, ||gradL(W)|| = 4.093389
# Iteration = 891, ||gradL(W)|| = 4.093389
# Iteration = 892, ||gradL(W)|| = 4.093389
# Iteration = 893, ||gradL(W)|| = 4.093389
# Iteration = 894, ||gradL(W)|| = 4.093389
# Iteration = 895, ||gradL(W)|| = 4.093389
# Iteration = 896, ||gradL(W)|| = 4.093389
# Iteration = 897, ||gradL(W)|| = 4.093389
# Iteration = 898, ||gradL(W)|| = 4.093389
# Iteration = 899, ||gradL(W)|| = 4.093389
# Iteration = 900, ||gradL(W)|| = 4.093389
# Iteration = 901, ||gradL(W)|| = 4.093389
# Iteration = 902, ||gradL(W)|| = 4.093389
# Iteration = 903, ||gradL(W)|| = 4.093389
# Iteration = 904, ||gradL(W)|| = 4.093389
# Iteration = 905, ||gradL(W)|| = 4.093389
# Iteration = 906, ||gradL(W)|| = 4.093389
# Iteration = 907, ||gradL(W)|| = 4.093389
# Iteration = 908, ||gradL(W)|| = 4.093389
# Iteration = 909, ||gradL(W)|| = 4.093389
# Iteration = 910, ||gradL(W)|| = 4.093389
# Iteration = 911, ||gradL(W)|| = 4.093389
# Iteration = 912, ||gradL(W)|| = 4.093389
# Iteration = 913, ||gradL(W)|| = 4.093389
# Iteration = 914, ||gradL(W)|| = 4.093389
# Iteration = 915, ||gradL(W)|| = 4.093389
# Iteration = 916, ||gradL(W)|| = 4.093389
# Iteration = 917, ||gradL(W)|| = 4.093389
# Iteration = 918, ||gradL(W)|| = 4.093389
# Iteration = 919, ||gradL(W)|| = 4.093389
# Iteration = 920, ||gradL(W)|| = 4.093389
# Iteration = 921, ||gradL(W)|| = 4.093389
# Iteration = 922, ||gradL(W)|| = 4.093389
# Iteration = 923, ||gradL(W)|| = 4.093389
# Iteration = 924, ||gradL(W)|| = 4.093389
# Iteration = 925, ||gradL(W)|| = 4.093389
# Iteration = 926, ||gradL(W)|| = 4.093389
# Iteration = 927, ||gradL(W)|| = 4.093389
# Iteration = 928, ||gradL(W)|| = 4.093389
# Iteration = 929, ||gradL(W)|| = 4.093389
# Iteration = 930, ||gradL(W)|| = 4.093389
# Iteration = 931, ||gradL(W)|| = 4.093389
# Iteration = 932, ||gradL(W)|| = 4.093389
# Iteration = 933, ||gradL(W)|| = 4.093389
# Iteration = 934, ||gradL(W)|| = 4.093389
# Iteration = 935, ||gradL(W)|| = 4.093389
# Iteration = 936, ||gradL(W)|| = 4.093389
# Iteration = 937, ||gradL(W)|| = 4.093389
# Iteration = 938, ||gradL(W)|| = 4.093389
# Iteration = 939, ||gradL(W)|| = 4.093389
# Iteration = 940, ||gradL(W)|| = 4.093389
# Iteration = 941, ||gradL(W)|| = 4.093389
# Iteration = 942, ||gradL(W)|| = 4.093389
# Iteration = 943, ||gradL(W)|| = 4.093389
# Iteration = 944, ||gradL(W)|| = 4.093389
# Iteration = 945, ||gradL(W)|| = 4.093389
# Iteration = 946, ||gradL(W)|| = 4.093389
# Iteration = 947, ||gradL(W)|| = 4.093389
# Iteration = 948, ||gradL(W)|| = 4.093389
# Iteration = 949, ||gradL(W)|| = 4.093389
# Iteration = 950, ||gradL(W)|| = 4.093389
# Iteration = 951, ||gradL(W)|| = 4.093389
# Iteration = 952, ||gradL(W)|| = 4.093389
# Iteration = 953, ||gradL(W)|| = 4.093389
# Iteration = 954, ||gradL(W)|| = 4.093389
# Iteration = 955, ||gradL(W)|| = 4.093389
# Iteration = 956, ||gradL(W)|| = 4.093389
# Iteration = 957, ||gradL(W)|| = 4.093389
# Iteration = 958, ||gradL(W)|| = 4.093389
# Iteration = 959, ||gradL(W)|| = 4.093389
# Iteration = 960, ||gradL(W)|| = 4.093389
# Iteration = 961, ||gradL(W)|| = 4.093389
# Iteration = 962, ||gradL(W)|| = 4.093389
# Iteration = 963, ||gradL(W)|| = 4.093389
# Iteration = 964, ||gradL(W)|| = 4.093389
# Iteration = 965, ||gradL(W)|| = 4.093389
# Iteration = 966, ||gradL(W)|| = 4.093389
# Iteration = 967, ||gradL(W)|| = 4.093389
# Iteration = 968, ||gradL(W)|| = 4.093389
# Iteration = 969, ||gradL(W)|| = 4.093389
# Iteration = 970, ||gradL(W)|| = 4.093389
# Iteration = 971, ||gradL(W)|| = 4.093389
# Iteration = 972, ||gradL(W)|| = 4.093389
# Iteration = 973, ||gradL(W)|| = 4.093389
# Iteration = 974, ||gradL(W)|| = 4.093389
# Iteration = 975, ||gradL(W)|| = 4.093389
# Iteration = 976, ||gradL(W)|| = 4.093389
# Iteration = 977, ||gradL(W)|| = 4.093389
# Iteration = 978, ||gradL(W)|| = 4.093389
# Iteration = 979, ||gradL(W)|| = 4.093389
# Iteration = 980, ||gradL(W)|| = 4.093389
# Iteration = 981, ||gradL(W)|| = 4.093389
# Iteration = 982, ||gradL(W)|| = 4.093389
# Iteration = 983, ||gradL(W)|| = 4.093389
# Iteration = 984, ||gradL(W)|| = 4.093389
# Iteration = 985, ||gradL(W)|| = 4.093389
# Iteration = 986, ||gradL(W)|| = 4.093389
# Iteration = 987, ||gradL(W)|| = 4.093389
# Iteration = 988, ||gradL(W)|| = 4.093389
# Iteration = 989, ||gradL(W)|| = 4.093389
# Iteration = 990, ||gradL(W)|| = 4.093389
# Iteration = 991, ||gradL(W)|| = 4.093389
# Iteration = 992, ||gradL(W)|| = 4.093389
# Iteration = 993, ||gradL(W)|| = 4.093389
# Iteration = 994, ||gradL(W)|| = 4.093389
# Iteration = 995, ||gradL(W)|| = 4.093389
# Iteration = 996, ||gradL(W)|| = 4.093389
# Iteration = 997, ||gradL(W)|| = 4.093389
# Iteration = 998, ||gradL(W)|| = 4.093389
# Iteration = 999, ||gradL(W)|| = 4.093389
# Iteration = 1000, ||gradL(W)|| = 4.093389
